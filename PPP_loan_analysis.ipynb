# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 53)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df1= pd.read_csv("public_150k_plus_220930.csv")
df2= pd.read_csv("public_up_to_150k_1_220930.csv")
df3= pd.read_csv("public_up_to_150k_2_220930.csv")
df4= pd.read_csv("public_up_to_150k_3_220930.csv")
df5= pd.read_csv("public_up_to_150k_4_220930.csv")
df6= pd.read_csv("public_up_to_150k_5_220930.csv")
df7= pd.read_csv("public_up_to_150k_6_220930.csv")
df8= pd.read_csv("public_up_to_150k_7_220930.csv")
df9= pd.read_csv("public_up_to_150k_8_220930.csv")
df10= pd.read_csv("public_up_to_150k_9_220930.csv")
df11= pd.read_csv("public_up_to_150k_10_220930.csv")
df12= pd.read_csv("public_up_to_150k_11_220930.csv")
df13= pd.read_csv("public_up_to_150k_12_220930.csv")
# Out:
# C:\Users\tpald\AppData\Local\Temp\ipykernel_32992\1496255280.py:5: DtypeWarning: Columns (50) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5= pd.read_csv("public_up_to_150k_4_220930.csv")
# C:\Users\tpald\AppData\Local\Temp\ipykernel_32992\1496255280.py:6: DtypeWarning: Columns (16,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6= pd.read_csv("public_up_to_150k_5_220930.csv")
# C:\Users\tpald\AppData\Local\Temp\ipykernel_32992\1496255280.py:8: DtypeWarning: Columns (50) have mixed types. Specify dtype option on import or set low_memory=False.
#   df8= pd.read_csv("public_up_to_150k_7_220930.csv")

# %%
df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13]

# %%
new_df = pd.concat(df_list)

# %%
new_df.head(1)
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020         464.00              PPP
#
#             BorrowerName        BorrowerAddress BorrowerCity BorrowerState  \
# 0  SUMTER COATINGS, INC.  2410 Highway 15 South       Sumter           NaN
#
#   BorrowerZip LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  \
# 0  29150-9662     12/18/2020  Paid in Full    24                    100
#
#    InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount  \
# 0              769358.78              769358.78               0.00
#
#   FranchiseName  ServicingLenderLocationID ServicingLenderName  \
# 0           NaN                   19248.00        Synovus Bank
#
#   ServicingLenderAddress ServicingLenderCity ServicingLenderState  \
# 0          1148 Broadway            COLUMBUS                   GA
#
#   ServicingLenderZip RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# ...

# %%
top20countryfreq = new_df.value_counts("OriginatingLender")[:20]

# %%
countrysum=new_df.groupby(['OriginatingLender']).agg({"CurrentApprovalAmount": "sum"}).sort_values("CurrentApprovalAmount", ascending=False)
top20countrysum=countrysum[:20]

# %%
state_list = [ "AE", 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
statesum= new_df.groupby(["BorrowerState", "OriginatingLender"], ).CurrentApprovalAmount.sum()

# %%
statesum2= new_df.groupby(["BorrowerState", "OriginatingLender"], as_index=False).CurrentApprovalAmount.sum()

# %%
statesum2.to_csv("statesum_update.csv")

# %%
statefreq= new_df.groupby(["BorrowerState","OriginatingLender"], , as_index=False).OriginatingLender.count()

# %%
statefreq.to_csv("freq.csv")

# %%
statefreq.to_csv("statesum_update.csv")

# %%
for state in state_list:
    print(state)
    print(statefreq[state].sort_values( ascending=False)[:20])
# Out:
# AE
# OriginatingLender
# Navy FCU                                     2
# JPMorgan Chase Bank, National Association    1
# Prestamos CDFI, LLC                          1
# Name: OriginatingLender, dtype: int64
# AK
# OriginatingLender
# Northrim Bank                             5627
# First National Bank Alaska                5349
# Alaska USA FCU                            2546
# First Bank                                1950
# Wells Fargo Bank, National Association    1667
# KeyBank National Association               759
# Denali State Bank                          723
# Mt. McKinley Bank                          593
# Matanuska Valley FCU                       424
# NuVision FCU                               377
# Celtic Bank Corporation                    322
# Cross River Bank                           258
# Square Capital, LLC                        203
# Prestamos CDFI, LLC                        153
# Customers Bank                             146
# ...
